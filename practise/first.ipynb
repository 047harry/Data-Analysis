# %% [markdown]
# <a href="https://colab.research.google.com/github/047harry/Data-Analysis/blob/main/practise/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Hemanth"
name.replace('h',"H")
# Out:
# 'HemantH'

# %%
job_title = "Data analyst so"
job_title = job_title.replace('a', "A")

print(job_title.split(" ", maxsplit=2))
# Out:
# ['DAtA', 'AnAlyst', 'so']

# %% [markdown]
# the arguements that are right of "\" in methods are **keyword arguements**
# and those are positional arguements.

# %%
"whatsapp\nguys"
# Out:
# 'whatsapp\nguys'

# %%
import random

years_experience = {
    "Alice": random.randint(1, 15),
    "Bob": random.randint(1, 15),
    "Charlie": random.randint(1, 15),
    "Diana": random.randint(1, 15),
    "Ethan": random.randint(1, 15),
    "Fiona": random.randint(1, 15),
    "George": random.randint(1, 15),
    "Hannah": random.randint(1, 15),
    "Ian": random.randint(1, 15),
    "Julia": random.randint(1, 15),
    "Kevin": random.randint(1, 15),
    "Laura": random.randint(1, 15),
    "Mike": random.randint(1, 15),
    "Nina": random.randint(1, 15),
    "Oscar": random.randint(1, 15),
    "Paula": random.randint(1, 15),
    "Quinn": random.randint(1, 15),
    "Rachel": random.randint(1, 15),
    "Sam": random.randint(1, 15),
    "Tina": random.randint(1, 15),
    "Umar": random.randint(1, 15),
    "Violet": random.randint(1, 15),
    "Will": random.randint(1, 15),
    "Xena": random.randint(1, 15),
    "Yusuf": random.randint(1, 15)
}

print(years_experience)

# %%
for items in years_experience.items():
  print(type(items))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
